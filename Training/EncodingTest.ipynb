# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import product
import torch
import torch.nn as nn
import cv2
from encoding import RF_convolution, encode_original, encode, RF_kernel
from parameter import TrainParam

# %%
image = cv2.imread('0.png',0)
image = RF_convolution(image,RF_kernel)
plt.imshow(image)
plt.show()

# %%
param = TrainParam(T=200, dt=1)

spiketrain = encode(image,param)
spiketrain.shape
# Out:
# (256, 201)

# %%
plt.plot(spiketrain[12])
plt.show()
